# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import os
# for dirname, _, filenames in os.walk('https://www.nbp.pl/kursy/Archiwum/'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# df0 = pd.read_csv('/kursy/Archiwum/publ_sredni_m_2012.csv')

# %% [markdown]
# ## Currency 2012

# %%
df2012 = pd.read_csv("data/publ_sredni_m_2012.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2012 = df2012.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2012.columns = ['index', '01.2012', '02.2012', '03.2012', '04.2012', '05.2012', '06.2012', '07.2012',
                  '08.2012', '09.2012', '10.2012', '11.2012', '12.2012']
df2012 = df2012.set_index('index')
df2012.swapaxes(axis1="index", axis2="columns")
df2012=df2012.T.reset_index()
df2012.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2012 = df2012[[ 'date', 'euro', "usd"]]

# %%
df2012
# Out:
# index     date    euro     usd
# 0      01.2012  4.3775  3.3884
# 1      02.2012  4.1840  3.1608
# 2      03.2012  4.1370  3.1320
# 3      04.2012  4.1756  3.1727
# 4      05.2012  4.2884  3.3472
# 5      06.2012  4.3072  3.4399
# 6      07.2012  4.1896  3.4061
# 7      08.2012  4.0912  3.3021
# 8      09.2012  4.1314  3.2154
# 9      10.2012  4.1091  3.1672
# 10     11.2012  4.1354  3.2237
# 11     12.2012  4.0938  3.1230

# %%
df2012.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2013

# %%
df2013 = pd.read_csv("data/publ_sredni_m_2013.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2013 = df2013.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2013.columns = ['index', '01.2013', '02.2013', '03.2013', '04.2013', '05.2013', '06.2013', '07.2013',
                  '08.2013', '09.2013', '10.2013', '11.2013', '12.2013']
df2013 = df2013.set_index('index')
df2013.swapaxes(axis1="index", axis2="columns")
df2013=df2013.T.reset_index()
df2013.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2013 = df2013[[ 'date', 'euro', "usd"]]

# %%
df2013
# Out:
# index     date    euro     usd
# 0      01.2013  4.1369  3.1145
# 1      02.2013  4.1734  3.1197
# 2      03.2013  4.1581  3.2058
# 3      04.2013  4.1409  3.1825
# 4      05.2013  4.1759  3.2149
# 5      06.2013  4.2865  3.2512
# 6      07.2013  4.2756  3.2688
# 7      08.2013  4.2295  3.1767
# 8      09.2013  4.2376  3.1750
# 9      10.2013  4.1908  3.0704
# 10     11.2013  4.1882  3.0998
# 11     12.2013  4.1757  3.0481

# %%
df2013.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2014

# %%
df2014 = pd.read_csv("data/publ_sredni_m_2014.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2014 = df2014.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2014.columns = ['index', '01.2014', '02.2014', '03.2014', '04.2014', '05.2014', '06.2014', '07.2014',
                  '08.2014', '09.2014', '10.2014', '11.2014', '12.2014']
df2014 = df2014.set_index('index')
df2014.swapaxes(axis1="index", axis2="columns")
df2014=df2014.T.reset_index()
df2014.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2014 = df2014[[ 'date', 'euro', "usd"]]

# %%
df2014
# Out:
# index     date    euro     usd
# 0      01.2014  4.1776  3.0650
# 1      02.2014  4.1786  3.0613
# 2      03.2014  4.1972  3.0378
# 3      04.2014  4.1841  3.0293
# 4      05.2014  4.1790  3.0415
# 5      06.2014  4.1369  3.0425
# 6      07.2014  4.1447  3.0598
# 7      08.2014  4.1932  3.1482
# 8      09.2014  4.1901  3.2475
# 9      10.2014  4.2050  3.3152
# 10     11.2014  4.2115  3.3777
# 11     12.2014  4.2233  3.4287

# %%
df2014.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2015

# %%
df2015 = pd.read_csv("data/publ_sredni_m_2015.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2015 = df2015.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2015.columns = ['index', '01.2015', '02.2015', '03.2015', '04.2015', '05.2015', '06.2015', '07.2015',
                  '08.2015', '09.2015', '10.2015', '11.2015', '12.2015']
df2015 = df2015.set_index('index')
df2015.swapaxes(axis1="index", axis2="columns")
df2015=df2015.T.reset_index()
df2015.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2015 = df2015[[ 'date', 'euro', "usd"]]

# %%
df2015
# Out:
# index     date    euro     usd
# 0      01.2015  4.2797  3.6739
# 1      02.2015  4.1776  3.6766
# 2      03.2015  4.1278  3.8138
# 3      04.2015  4.0291  3.7347
# 4      05.2015  4.0783  3.6520
# 5      06.2015  4.1597  3.7103
# 6      07.2015  4.1540  3.7734
# 7      08.2015  4.1936  3.7685
# 8      09.2015  4.2169  3.7513
# 9      10.2015  4.2460  3.7807
# 10     11.2015  4.2503  3.9571
# 11     12.2015  4.2905  3.9417

# %%
df2015.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2016

# %%
df2016 = pd.read_csv("data/publ_sredni_m_2016.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2016 = df2016.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2016.columns = ['index', '01.2016', '02.2016', '03.2016', '04.2016', '05.2016', '06.2016', '07.2016',
                  '08.2016', '09.2016', '10.2016', '11.2016', '12.2016']
df2016 = df2016.set_index('index')
df2016.swapaxes(axis1="index", axis2="columns")
df2016 = df2016.T.reset_index()
df2016.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2016 = df2016[[ 'date', 'euro', "usd"]]

# %%
df2016
# Out:
# index     date    euro     usd
# 0      01.2016  4.3935  4.0397
# 1      02.2016  4.3960  3.9565
# 2      03.2016  4.2934  3.8644
# 3      04.2016  4.3068  3.7985
# 4      05.2016  4.4076  3.8991
# 5      06.2016  4.4019  3.9200
# 6      07.2016  4.3966  3.9707
# 7      08.2016  4.3003  3.8354
# 8      09.2016  4.3250  3.8567
# 9      10.2016  4.3086  3.9075
# 10     11.2016  4.3839  4.0600
# 11     12.2016  4.4371  4.2049

# %%
df2016.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2017

# %%
df2017 = pd.read_csv("data/publ_sredni_m_2017.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2017 = df2017.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2017.columns = ['index', '01.2017', '02.2017', '03.2017', '04.2017', '05.2017', '06.2017', '07.2017',
                  '08.2017', '09.2017', '10.2017', '11.2017', '12.2017']
df2017 = df2017.set_index('index')
df2017.swapaxes(axis1="index", axis2="columns")
df2017 = df2017.T.reset_index()
df2017.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2017 = df2017[[ 'date', 'euro', "usd"]]

# %%
df2017
# Out:
# index     date    euro     usd
# 0      01.2017  4.3706  4.1166
# 1      02.2017  4.3097  4.0487
# 2      03.2017  4.2921  4.0184
# 3      04.2017  4.2385  3.9562
# 4      05.2017  4.2040  3.8070
# 5      06.2017  4.2083  3.7504
# 6      07.2017  4.2361  3.6805
# 7      08.2017  4.2665  3.6127
# 8      09.2017  4.2702  3.5799
# 9      10.2017  4.2668  3.6303
# 10     11.2017  4.2293  3.6031
# 11     12.2017  4.2016  3.5482

# %%
df2017.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2018

# %%
df2018 = pd.read_csv("data/publ_sredni_m_2018.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2018 = df2018.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2018.columns = ['index', '01.2018', '02.2018', '03.2018', '04.2018', '05.2018', '06.2018', '07.2018',
                  '08.2018', '09.2018', '10.2018', '11.2018', '12.2018']
df2018 = df2018.set_index('index')
df2018.swapaxes(axis1="index", axis2="columns")
df2018 = df2018.T.reset_index()
df2018.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2018 = df2018[[ 'date', 'euro', "usd"]]

# %%
df2018
# Out:
# index     date    euro     usd
# 0      01.2018  4.1636  3.4141
# 1      02.2018  4.1683  3.3701
# 2      03.2018  4.2101  3.4158
# 3      04.2018  4.1948  3.4188
# 4      05.2018  4.2820  3.6183
# 5      06.2018  4.3054  3.6876
# 6      07.2018  4.3301  3.7095
# 7      08.2018  4.2873  3.7175
# 8      09.2018  4.2992  3.6837
# 9      10.2018  4.3060  3.7495
# 10     11.2018  4.3029  3.7866
# 11     12.2018  4.2905  3.7691

# %%
df2018.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2019

# %%
df2019 = pd.read_csv("data/publ_sredni_m_2019.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2019 = df2019.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2019.columns = ['index', '01.2019', '02.2019', '03.2019', '04.2019', '05.2019', '06.2019', '07.2019',
                  '08.2019', '09.2019', '10.2019', '11.2019', '12.2019']
df2019 = df2019.set_index('index')
df2019.swapaxes(axis1="index", axis2="columns")
df2019 = df2019.T.reset_index()
df2019.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2019 = df2019[[ 'date', 'euro', "usd"]]

# %%
df2019
# Out:
# index     date    euro     usd
# 0      01.2019  4.2954  3.7617
# 1      02.2019  4.3157  3.8023
# 2      03.2019  4.2996  3.8052
# 3      04.2019  4.2874  3.8145
# 4      05.2019  4.2965  3.8393
# 5      06.2019  4.2660  3.7811
# 6      07.2019  4.2598  3.7959
# 7      08.2019  4.3437  3.9067
# 8      09.2019  4.3547  3.9535
# 9      10.2019  4.3025  3.8935
# 10     11.2019  4.2843  3.8745
# 11     12.2019  4.2721  3.8443

# %%
df2019.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2020

# %%
df2020 = pd.read_csv("data/publ_sredni_m_2020.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2020 = df2020.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2020.columns = ['index', '01.2020', '02.2020', '03.2020', '04.2020', '05.2020', '06.2020', '07.2020',
                  '08.2020', '09.2020', '10.2020', '11.2020', '12.2020']
df2020 = df2020.set_index('index')
df2020.swapaxes(axis1="index", axis2="columns")
df2020 = df2020.T.reset_index()
df2020.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2020 = df2020[[ 'date', 'euro', "usd"]]

# %%
df2020
# Out:
# index     date    euro     usd
# 0      01.2020  4.2504  3.8287
# 1      02.2020  4.2789  3.9201
# 2      03.2020  4.4356  4.0126
# 3      04.2020  4.5450  4.1856
# 4      05.2020  4.5291  4.1569
# 5      06.2020  4.4450  3.9453
# 6      07.2020  4.4528  3.8943
# 7      08.2020  4.4021  3.7190
# 8      09.2020  4.4740  3.7926
# 9      10.2020  4.5411  3.8605
# 10     11.2020  4.5023  3.8035
# 11     12.2020  4.4766  3.6778

# %%
df2020.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2021

# %%
df2021 = pd.read_csv("data/publ_sredni_m_2021.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2021 = df2021.drop(columns=['kod', 'liczba jednostek', 'Unnamed: 15'])
df2021.columns = ['index', '01.2021', '02.2021', '03.2021', '04.2021', '05.2021', '06.2021', '07.2021',
                  '08.2021', '09.2021', '10.2021', '11.2021', '12.2021']
df2021 = df2021.set_index('index')
df2021.swapaxes(axis1="index", axis2="columns")
df2021 = df2021.T.reset_index()
df2021.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2021 = df2021[[ 'date', 'euro', "usd"]]

# %%
df2021
# Out:
# index     date    euro     usd
# 0      01.2021  4.5435  3.7304
# 1      02.2021  4.4988  3.7196
# 2      03.2021  4.6007  3.8673
# 3      04.2021  4.5658  3.8212
# 4      05.2021  4.5301  3.7292
# 5      06.2021  4.5015  3.7375
# 6      07.2021  4.5630  3.8592
# 7      08.2021  4.5700  3.8835
# 8      09.2021  4.5664  3.8755
# 9      10.2021  4.5952  3.9607
# 10     11.2021  4.6508  4.0755
# 11     12.2021  4.6163  4.0834

# %%
df2021.describe().plot(kind = 'bar');

# %% [markdown]
# ## Currency 2022

# %%
df2022 = pd.read_csv("data/publ_sredni_m_2022.csv", sep = ';',  encoding = 'ISO-8859-1', decimal=',')
df2022 = df2022.drop(columns=['kod', 'liczba jednostek'])
df2022.columns = ['index', '01.2022', '02.2022', '03.2022', '04.2022', '05.2022', '06.2022', '07.2022',
                  '08.2022', '09.2022', '10.2022', '11.2022', '12.2022']
df2022 = df2022.set_index('index')
df2022.swapaxes(axis1="index", axis2="columns")
df2022 = df2022.T.reset_index()
df2022.rename(columns = {'index':'date', 'dolar amerykañski':'usd'}, inplace = True)
df2022 = df2022[[ 'date', 'euro', "usd"]]

# %%
df2022
# Out:
# index     date    euro     usd
# 0      01.2022  4.5548  4.0239
# 1      02.2022  4.5539  4.0156
# 2      03.2022  4.7603  4.3207
# 3      04.2022  4.6465  4.2899
# 4      05.2022  4.6503  4.3987
# 5      06.2022  4.6457  4.3876
# 6      07.2022  4.7712  4.6831
# 7      08.2022  4.7216  4.6578
# 8      09.2022     NaN     NaN
# 9      10.2022     NaN     NaN
# 10     11.2022     NaN     NaN
# 11     12.2022     NaN     NaN

# %%
df2022.describe().plot(kind = 'bar');

# %% [markdown]
# ## all currency 2012 - 2022

# %%
currency = pd.concat([df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021, df2022], axis=0)
currency = currency.reset_index(drop=True)
currency['date'] = pd.to_datetime(currency['date'], format= '%m.%Y')
currency
# Out:
# index       date    euro     usd
# 0     2012-01-01  4.3775  3.3884
# 1     2012-02-01  4.1840  3.1608
# 2     2012-03-01  4.1370  3.1320
# 3     2012-04-01  4.1756  3.1727
# 4     2012-05-01  4.2884  3.3472
# ..           ...     ...     ...
# 127   2022-08-01  4.7216  4.6578
# 128   2022-09-01     NaN     NaN
# 129   2022-10-01     NaN     NaN
# 130   2022-11-01     NaN     NaN
# 131   2022-12-01     NaN     NaN
#
# [132 rows x 3 columns]

# %%
currency.describe()
# Out:
# index        euro         usd
# count  128.000000  128.000000
# mean     4.317309    3.672579
# std      0.160792    0.365628
# min      4.029100    3.029300
# 25%      4.192600    3.375800
# 50%      4.286900    3.750850
# 75%      4.401950    3.895500
# max      4.771200    4.683100

# %%
currency.describe().loc[[ 'min',  '25%',  'mean', '50%', '75%', 'max', ]].plot(kind = 'bar', 
                    title = 'Currency Prices 2012 - 2022', figsize=(14,7));

# %%
currency_melted = currency.melt(id_vars=['date'], var_name='currency', value_name='price')
currency_melted
# Out:
#           date currency   price
# 0   2012-01-01     euro  4.3775
# 1   2012-02-01     euro  4.1840
# 2   2012-03-01     euro  4.1370
# 3   2012-04-01     euro  4.1756
# 4   2012-05-01     euro  4.2884
# ..         ...      ...     ...
# 259 2022-08-01      usd  4.6578
# 260 2022-09-01      usd     NaN
# 261 2022-10-01      usd     NaN
# 262 2022-11-01      usd     NaN
# 263 2022-12-01      usd     NaN
#
# [264 rows x 3 columns]

# %%
plt.figure(figsize=(14,7))

# pis line on red
plt.axvline(pd.to_datetime('2015-01-01'), color='r', linestyle='--', lw=2)


plt.title('USD & EURO Currency from 2012 to 2022')
sns.lineplot(x = 'date', y = 'price', hue = 'currency', data = currency_melted);

# %%
currency.to_csv('currency.csv', index=False)
